# %% [markdown]
# # Mini-Project: Data Wrangling and Transformation with Pandas
#
# Working with tabular data is a necessity for anyone with enterprises having a majority of their data in relational databases and flat files. This mini-project is adopted from the excellent tutorial on pandas by Brandon Rhodes which you have watched earlier in the Data Wrangling Unit. In this mini-project, we will be looking at some interesting data based on movie data from the IMDB.
#
# This assignment should help you reinforce the concepts you learnt in the curriculum for Data Wrangling and sharpen your skills in using Pandas. Good Luck!

# %% [markdown]
# ### Please make sure you have one of the more recent versions of Pandas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
pd.__version__
# Out:
# '1.3.4'

# %% [markdown]
# ## Taking a look at the Movies dataset
# This data shows the movies based on their title and the year of release

# %%
movies = pd.read_csv('titles.csv')
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244914 entries, 0 to 244913
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   title   244914 non-null  object
#  1   year    244914 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 3.7+ MB

# %%
movies.head()
# Out:
#                                           title  year
# 0                        The Ticket to the Life  2009
# 1  Parallel Worlds: A New Rock Music Experience  2016
# 2                     Morita - La hija de Jesus  2008
# 3                                           Gun  2017
# 4                        Love or Nothing at All  2014

# %% [markdown]
# ## Taking a look at the Cast dataset
#
# This data shows the cast (actors, actresses, supporting roles) for each movie
#
# - The attribute `n` basically tells the importance of the cast role, lower the number, more important the role.
# - Supporting cast usually don't have any value for `n`

# %%
cast = pd.read_csv('cast.csv.zip')
cast.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3786176 entries, 0 to 3786175
# Data columns (total 6 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   title      object
#  1   year       int64
#  2   name       object
#  3   type       object
#  4   character  object
#  5   n          float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 173.3+ MB

# %%
cast.head(30)
# Out:
#                                                 title  year  \
# 0                                      Closet Monster  2015
# 1                                     Suuri illusioni  1985
# 2                                 Battle of the Sexes  2017
# 3                                Secret in Their Eyes  2015
# 4                                          Steve Jobs  2015
# 5                              Straight Outta Compton  2015
# 6                              Straight Outta Compton  2015
# 7                                      For Thy Love 2  2009
# 8   Lapis, Ballpen at Diploma, a True to Life Journey  2014
# 9                                        Desire (III)  2014
# 10                            When the Man Went South  2014
# 11                            Little Angel (Angelita)  2015
# 12                                         Mixing Nia  1998
# 13                                   The Replacements  2000
# 14                               All Out Dysfunktion!  2016
# ...

# %% [markdown]
# ## Taking a look at the Release dataset
#
# This data shows details of when each movie was release in each country with the release date

# %%
release_dates = pd.read_csv('release_dates.csv', parse_dates=['date'], infer_datetime_format=True)
release_dates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479488 entries, 0 to 479487
# Data columns (total 4 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   title    479488 non-null  object
#  1   year     479488 non-null  int64
#  2   country  479488 non-null  object
#  3   date     479488 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 14.6+ MB

# %%
release_dates.head()
# Out:
#                     title  year      country       date
# 0   #73, Shaanthi Nivaasa  2007        India 2007-06-15
# 1                   #BKKY  2016     Cambodia 2017-10-12
# 2                 #Beings  2015      Romania 2015-01-29
# 3               #Captured  2017          USA 2017-09-05
# 4  #Ewankosau saranghaeyo  2015  Philippines 2015-01-21

# %% [markdown]
# # Section I - Basic Querying, Filtering and Transformations

# %% [markdown]
# ### What is the total number of movies?

# %%
len(movies)
# Out:
# 244914

# %% [markdown]
# ### List all Batman movies ever made

# %%
batman_df = movies[movies.title == 'Batman']
print('Total Batman Movies:', len(batman_df))
batman_df
# Out:
# Total Batman Movies: 2
#          title  year
# 52734   Batman  1943
# 150621  Batman  1989

# %% [markdown]
# ### List all Batman movies ever made - the right approach

# %%
batman_df = movies[movies.title.str.contains('Batman', case=False)]
print('Total Batman Movies:', len(batman_df))
batman_df.head(10)
# Out:
# Total Batman Movies: 35
#                                              title  year
# 16813                              Batman: Anarchy  2016
# 30236                               Batman Forever  1995
# 31674                                Batman Untold  2010
# 31711  Scooby-Doo & Batman: the Brave and the Bold  2018
# 41881                  Batman the Rise of Red Hood  2018
# 43484        Batman: Return of the Caped Crusaders  2016
# 46333                               Batman & Robin  1997
# 51811                              Batman Revealed  2012
# 52734                                       Batman  1943
# 56029                 Batman Beyond: Rising Knight  2014

# %% [markdown]
# ### Display the top 15 Batman movies in the order they were released

# %%
batman_df.sort_values(by=['year'], ascending=True).iloc[:15]
# Out:
#                                title  year
# 52734                         Batman  1943
# 100056              Batman and Robin  1949
# 161439                Batman Dracula  1964
# 84327          Alyas Batman at Robin  1965
# 68364                   James Batman  1966
# 161527             Batman: The Movie  1966
# 56159          Batman Fights Dracula  1967
# 168504         Fight! Batman, Fight!  1973
# 150621                        Batman  1989
# 156239         Alyas Batman en Robin  1991
# 156755                Batman Returns  1992
# 63366   Batman: Mask of the Phantasm  1993
# 30236                 Batman Forever  1995
# 46333                 Batman & Robin  1997
# 208220                 Batman Begins  2005

# %% [markdown]
# ### Section I - Q1 : List all the 'Harry Potter' movies from the most recent to the earliest

# %%
HarryPotter_df = movies[movies.title.str.contains('Harry Potter', case=False)].sort_values(by=['year'], ascending=False)
print('Total Harry Potter Movies:', len(HarryPotter_df))
HarryPotter_df
# Out:
# Total Harry Potter Movies: 8
#                                                title  year
# 143147  Harry Potter and the Deathly Hallows: Part 2  2011
# 152831  Harry Potter and the Deathly Hallows: Part 1  2010
# 109213        Harry Potter and the Half-Blood Prince  2009
# 50581      Harry Potter and the Order of the Phoenix  2007
# 187926           Harry Potter and the Goblet of Fire  2005
# 61957       Harry Potter and the Prisoner of Azkaban  2004
# 82791        Harry Potter and the Chamber of Secrets  2002
# 223087         Harry Potter and the Sorcerer's Stone  2001

# %% [markdown]
# ### How many movies were made in the year 2017?

# %%
len(movies[movies.year == 2017])
# Out:
# 11474

# %% [markdown]
# ### Section I - Q2 : How many movies were made in the year 2015?

# %%
len(movies[movies.year == 2015])
# Out:
# 8702

# %% [markdown]
# ### Section I - Q3 : How many movies were made from 2000 till 2018?
# - You can chain multiple conditions using OR (`|`) as well as AND (`&`) depending on the condition

# %%
len(movies[(movies.year >= 2000) & (movies.year <= 2018)])
# Out:
# 114070

# %% [markdown]
# ### Section I - Q4: How many movies are titled "Hamlet"?

# %%
len(movies[movies.title.str.contains('Hamlet', case=False)])
# Out:
# 57

# %% [markdown]
# ### Section I - Q5: List all movies titled "Hamlet"
# - The movies should only have been released on or after the year 2000
# - Display the movies based on the year they were released (earliest to most recent)

# %%
movies[(movies.title.str.contains('Hamlet', case=False)) & (movies.year>=2000)].sort_values(by=['year'], ascending=True)
# Out:
#                                           title  year
# 55639                                    Hamlet  2000
# 55525                    Hamlet in the Hamptons  2002
# 137905                                 Hamlet_X  2003
# 218468                                 Hamlet X  2004
# 40045                               Hamlet (II)  2005
# 152920          Dogg's Hamlet, Cahoot's Macbeth  2005
# 200246  The Tragedy of Hamlet Prince of Denmark  2007
# 176528                              Hamlet (II)  2007
# 156899                             Hamlet (III)  2007
# 52408                 Hamlet the Vampire Slayer  2008
# 141237                                 Hamlet 2  2008
# 191734                           Kitchen Hamlet  2009
# 1931                                     Hamlet  2009
# 227953                                   Hamlet  2011
# 220674                     Hamlet Demonstration  2011
# 51236                            Hamlet Unbound  2012
# ...

# %% [markdown]
# ### Section I - Q6: How many roles in the movie "Inception" are of the supporting cast (extra credits)
# - supporting cast are NOT ranked by an "n" value (NaN)
# - check for how to filter based on nulls

# %%
len(cast[(cast.title.str.contains('Inception', case=False) & cast.n.isnull())])
# Out:
# 36

# %% [markdown]
# ### Section I - Q7: How many roles in the movie "Inception" are of the main cast
# - main cast always have an 'n' value

# %%
len(cast[(cast.title.str.contains('Inception', case=False) & cast.n.notnull())])
# Out:
# 51

# %% [markdown]
# ### Section I - Q8: Show the top ten cast (actors\actresses) in the movie "Inception"
# - main cast always have an 'n' value
# - remember to sort!

# %%
CastInInception = cast[(cast.title.str.contains('Inception', case=False)) & (cast.n.notnull())].sort_values(by='n', ascending=False)
CastInInception.head(10)
# Out:
#              title  year                name     type              character  \
# 3731263  Inception  2010      Shannon Welles  actress                Old Mal
# 833376   Inception  2010         Jack Gilroy    actor               Old Cobb
# 2250605  Inception  2010       Jason Tendell    actor       Fischer's Driver
# 3473041  Inception  2010  Lisa (II) Reynolds  actress          Private Nurse
# 1812091  Inception  2010      Andrew Pleavin    actor            Businessman
# 2049179  Inception  2010         Felix Scott    actor            Businessman
# 807795   Inception  2010      Michael Gaston    actor    Immigration Officer
# 149008   Inception  2010        Peter Basham    actor  Fischer's Jet Captain
# 3444628  Inception  2010      Nicole Pulliam  actress          Lobby Sub Con
# 3203564  Inception  2010   Alex (II) Lombard  actress          Lobby Sub Con
#
#             n
# 3731263  51.0
# 833376   50.0
# 2250605  49.0
# 3473041  48.0
# 1812091  47.0
# 2049179  46.0
# ...

# %% [markdown]
# ### Section I - Q9:
#
# (A) List all movies where there was a character 'Albus Dumbledore'
#
# (B) Now modify the above to show only the actors who played the character 'Albus Dumbledore'
# - For Part (B) remember the same actor might play the same role in multiple movies

# %%
cast[cast.character.str.contains('Albus Dumbledore', case=False)]
# Out:
#                                                 title  year  \
# 704984                                     Epic Movie  2007
# 792419   Harry Potter and the Deathly Hallows: Part 1  2010
# 792420   Harry Potter and the Deathly Hallows: Part 2  2011
# 792421            Harry Potter and the Goblet of Fire  2005
# 792422         Harry Potter and the Half-Blood Prince  2009
# 792423      Harry Potter and the Order of the Phoenix  2007
# 792424       Harry Potter and the Prisoner of Azkaban  2004
# 947789        Harry Potter and the Chamber of Secrets  2002
# 947790          Harry Potter and the Sorcerer's Stone  2001
# 1685537                         Ultimate Hero Project  2013
# 1893421  Harry Potter and the Deathly Hallows: Part 1  2010
# 2248085                                        Potter  2015
#
#                         name   type                   character     n
# 704984          Dane Farwell  actor            Albus Dumbledore  17.0
# ...

# %%
cast[cast.character.str.contains('Albus Dumbledore', case=False)].name.unique()
# Out:
# array(['Dane Farwell', 'Michael Gambon', 'Richard Harris',
#        "George (X) O'Connor", 'Toby Regbo', 'Timothy Tedmanson'],
#       dtype=object)

# %% [markdown]
# ### Section I - Q10:
#
# (A) How many roles has 'Keanu Reeves' played throughout his career?
#
# (B) List the leading roles that 'Keanu Reeves' played on or after 1999 in order by year.

# %%
cast[(cast.name.str.contains('Keanu Reeves', case=False)) & (cast.year >= 1999)].sort_values(by='year', ascending=True).loc[:, ['character', 'year']]
# Out:
#                     character  year
# 1892370               Himself  1999
# 1892369               Dogstar  1999
# 1892390                   Neo  1999
# 1892387      Donnie Barksdale  2000
# 1892398               Griffin  2000
# 1892397           Shane Falco  2000
# 1892383           Nelson Moss  2001
# 1892358         Conor O'Neill  2001
# 1892391                   Neo  2003
# 1892379         Julian Mercer  2003
# 1892392                   Neo  2003
# 1892351               Dogstar  2005
# 1892348      John Constantine  2005
# 1892400           Perry Lyman  2005
# 1892388            Alex Wyler  2006
# 1892343            Bob Arctor  2006
# 1892382  Detective Tom Ludlow  2008
# 1892385                Klaatu  2008
# 1892396          Chris Nadeau  2009
# 1892359           Henry Torne  2010
# 1892357                  John  2012
# 1892342                   Kai  2013
# 1892368           Donaka Mark  2013
# 1892361             John Wick  2014
# 1892366                  Evan  2015
# ...

# %% [markdown]
# ### Section I - Q11:
#
# (A) List the total number of actor and actress roles available from 1950 - 1960
#
# (B) List the total number of actor and actress roles available from 2007 - 2017

# %%
len(cast[((cast.year>=1950) & (cast.year<=1960))].name.unique())
# Out:
# 55516

# %%
len(cast[((cast.year>=2007) & (cast.year<=2017))].name.unique())
# Out:
# 791489

# %% [markdown]
# ### Section I - Q12:
#
# (A) List the total number of leading roles available from 2000 to present
#
# (B) List the total number of non-leading roles available from 2000 - present (exclude support cast)
#
# (C) List the total number of support\extra-credit roles available from 2000 - present

# %% [markdown]
# ### ??? Question - not sure what is the leading role definition here

# %% [markdown]
# # Section II - Aggregations, Transformations and Visualizations

# %% [markdown]
# ## What are the top ten most common movie names of all time?
# #### Is it correct??? (this code was from orginal notebook)

# %%
top_ten = movies.title.value_counts()[:10]
top_ten
# Out:
# Hamlet                  20
# Carmen                  17
# Macbeth                 16
# Maya                    12
# Temptation              12
# The Outsider            12
# Freedom                 11
# The Three Musketeers    11
# Honeymoon               11
# Othello                 11
# Name: title, dtype: int64

# %% [markdown]
# ### Plot the top ten common movie names of all time

# %%
top_ten.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Section II - Q1:  Which years in the 2000s saw the most movies released? (Show top 3)

# %%
yMax = movies[movies.year>1999].groupby(['year'])['year'].count().idxmax()
cMax = movies[movies.year>1999].groupby(['year'])['year'].count().max()
print ("in", yMax, "has the most of movies", cMax)
# Out:
# in 2017 has the most of movies 11474

# %%
a = movies[movies.year>1999].groupby(['year'])['year'].count()
type(a)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Section II - Q2: # Plot the total number of films released per-decade (1890, 1900, 1910,....)
# - Hint: Dividing the year and multiplying with a number might give you the decade the year falls into!
# - You might need to sort before plotting

# %%
movies['decade'] = movies.year//10*10
mCountByDecade = movies.groupby(['decade'])['decade'].count()
mCountByDecade
# Out:
# decade
# 1890        3
# 1900       39
# 1910     6799
# 1920     9034
# 1930    10388
# 1940     8718
# 1950    12934
# 1960    17976
# 1970    19526
# 1980    21034
# 1990    22992
# 2000    39452
# 2010    75733
# 2020      285
# 2110        1
# Name: decade, dtype: int64

# %%
plt.rcParams["figure.figsize"] = (10,3)
type(mCountByDecade)
# Out:
# pandas.core.series.Series

# %%
mCountByDecade.plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='decade'>

# %% [markdown]
# ### Section II - Q3:
#
# (A) What are the top 10 most common character names in movie history?
#
# (B) Who are the top 10 people most often credited as "Herself" in movie history?
#
# (C) Who are the top 10 people most often credited as "Himself" in movie history?

# %%
cast.groupby(['character'])['character'].count().sort_values(ascending=False).head(10)
# Out:
# character
# Himself        20746
# Dancer         12477
# Extra          11948
# Reporter        8434
# Student         7773
# Doctor          7669
# Party Guest     7245
# Policeman       7029
# Nurse           6999
# Bartender       6802
# Name: character, dtype: int64

# %%
cast[cast.character == 'Herself'].groupby(['name'])['name'].count().sort_values(ascending=False).head(10)
# Out:
# name
# Queen Elizabeth II        12
# Joyce Brothers             9
# Luisa Horga                9
# Mar?a Luisa (V) Mart?n     9
# Hillary Clinton            8
# Margaret Thatcher          8
# In?s J. Southern           6
# Marta Berrocal             6
# Oprah Winfrey              6
# Marilyn Monroe             6
# Name: name, dtype: int64

# %%
cast[cast.character == 'Himself'].groupby(['name'])['name'].count().sort_values(ascending=False).head(10)
# Out:
# name
# Adolf Hitler             99
# Richard Nixon            44
# Ronald Reagan            41
# John F. Kennedy          37
# George W. Bush           25
# Winston Churchill        24
# Martin Luther King       23
# Bill Clinton             22
# Ron Jeremy               22
# Franklin D. Roosevelt    21
# Name: name, dtype: int64

# %% [markdown]
# ### Section II - Q4:
#
# (A) What are the top 10 most frequent roles that start with the word "Zombie"?
#
# (B) What are the top 10 most frequent roles that start with the word "Police"?
#
# - Hint: The `startswith()` function might be useful

# %%
cast[cast.character.str.startswith('Zombie')].groupby(['name'])['name'].count().sort_values(ascending=False).head(10)
# Out:
# name
# John (II) Migliore    9
# Colin Murtagh         7
# S. William Hinzman    4
# Clive McKenzie        4
# Josephine Streiner    3
# Roy Martin Thorn      3
# John (XVIII) Cross    3
# Richard Ricci         3
# Terry Gindele         3
# Ross Harris           3
# Name: name, dtype: int64

# %%
cast[cast.character.str.startswith('Police')].groupby(['name'])['name'].count().sort_values(ascending=False).head(10)
# Out:
# name
# Brick Sullivan    93
# Chuck Hamilton    82
# Lee Phelps        76
# Frank O'Connor    72
# Wade Boteler      70
# Robert Homans     69
# Dick Rush         68
# Edgar Dearing     59
# Jagdish Raj       58
# James Flavin      57
# Name: name, dtype: int64

# %% [markdown]
# ### Section II - Q5: Plot how many roles 'Keanu Reeves' has played in each year of his career.

# %%
rolesKRplayed = cast[cast.name=='Keanu Reeves'].groupby('year')['year'].count()
rolesKRplayed.plot(kind='bar', ylabel='# of roles played')
#rolesKRplayed.plot?
# Out:
# <AxesSubplot:xlabel='year', ylabel='# of roles played'>

# %% [markdown]
# ### Section II - Q6: Plot the cast positions (n-values) of Keanu Reeve's roles through his career over the years.

# %%
KR = cast[cast.name=='Keanu Reeves']
KR.loc[:,['year', 'n']]
#KR.plot(data[:kind='scatter'
plt.rcParams['figure.figsize'] = (10, 5)
plt.plot(KR.year, KR.n, 'bo')
plt.xlabel('year')
plt.ylabel('n - cast positions')
plt.title("Cast Positions (n-values) of Keanu Reeve's Roles through His Career")
# Out:
# Text(0.5, 1.0, "Cast Positions (n-values) of Keanu Reeve's Roles through His Career")

# %% [markdown]
# ### Section II - Q7: Plot the number of "Hamlet" films made by each decade

# %%
movies[movies.title.str.contains('Hamlet')].groupby('decade')['year'].count().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='decade'>

# %% [markdown]
# ### Section II - Q8:
#
# (A) How many leading roles were available to both actors and actresses, in the 1960s (1960-1969)?
#
# (B) How many leading roles were available to both actors and actresses, in the 2000s (2000-2009)?
#
# - Hint: A specific value of n might indicate a leading role

# %%
print("Leading roles in the 1960s:")
cast[(cast.n==1) & ((cast.year>=1960) & (cast.year<=1969))].groupby(['type'])['name'].count()
# Out:
# Leading roles in the 1960s:
# type
# actor      8320
# actress    3503
# Name: name, dtype: int64

# %% [markdown]
# ### Section II - Q9: List, in order by year, each of the films in which Frank Oz has played more than 1 role.

# %%
nRolesFO = cast[cast.name=='Frank Oz'].groupby(['year', 'title'])['n'].count().rename('Numner of roles')
nRolesFO[nRolesFO.values > 1]
# Out:
# year  title
# 1979  The Muppet Movie                        8
# 1981  An American Werewolf in London          2
#       The Great Muppet Caper                  6
# 1982  The Dark Crystal                        2
# 1984  The Muppets Take Manhattan              7
# 1985  Follow That Bird                        3
# 1992  The Muppet Christmas Carol              7
# 1996  Muppet Treasure Island                  4
# 1999  Muppets from Space                      4
#       The Adventures of Elmo in Grouchland    3
# Name: Numner of roles, dtype: int64

# %% [markdown]
# ### Section II - Q10: List each of the characters that Frank Oz has portrayed at least twice

# %%
ncFO = cast[cast.name=='Frank Oz'].groupby('character')['n'].count().rename("Number of Characters Franl Oz Portrayed")
ncFO[ncFO.values>1]
# Out:
# character
# Animal            6
# Bert              3
# Cookie Monster    4
# Fozzie Bear       4
# Grover            2
# Miss Piggy        6
# Sam the Eagle     5
# Yoda              5
# Name: Number of Characters Franl Oz Portrayed, dtype: int64

# %% [markdown]
# # Section III - Advanced Merging, Querying and Visualizations

# %% [markdown]
# ## Make a bar plot with the following conditions
# - Frequency of the number of movies with "Christmas" in their title
# - Movies should be such that they are released in the USA.
# - Show the frequency plot by month

# %%
christmas = release_dates[(release_dates.title.str.contains('Christmas')) & (release_dates.country == 'USA')]
christmas.date.dt.month.value_counts().sort_index().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Section III - Q1: Make a bar plot with the following conditions
# - Frequency of the number of movies with "Summer" in their title
# - Movies should be such that they are released in the USA.
# - Show the frequency plot by month

# %%
SummerUSA = release_dates[(release_dates.title.str.contains('Summer', case=False)) & (release_dates.country=='USA')]
SummerUSA.date.dt.month.value_counts().sort_index().plot(kind='bar')
plt.xlabel('month')
plt.ylabel('# of Movies')
plt.title('Frquency of the Number of movies with Summer in title and released in USA')
#SummerUSA
# Out:
# Text(0.5, 1.0, 'Frquency of the Number of movies with Summer in title and released in USA')

# %% [markdown]
# ### Section III - Q2: Make a bar plot with the following conditions
# - Frequency of the number of movies with "Action" in their title
# - Movies should be such that they are released in the USA.
# - Show the frequency plot by week

# %%
ActionUSA = release_dates[(release_dates.title.str.contains('Action', case=False)) & (release_dates.country=='USA')]
ActionUSA.date.dt.day_of_week.value_counts().sort_index().plot(kind='bar')
plt.xlabel('day of week')
plt.ylabel('# of Movies')
plt.xticks(range(0,7), labels=('Mon, Tue, Wed, Thu, Fri, Sat, Sun'.split(',')))
plt.title('Frquency of the Number of movies with Action in title and released in USA')
# Out:
# Text(0.5, 1.0, 'Frquency of the Number of movies with Action in title and released in USA')

# %% [markdown]
# ### Section III - Q3: Show all the movies in which Keanu Reeves has played the lead role along with their   release date in the USA sorted by the date of release
# - Hint: You might need to join or merge two datasets!

# %%
pd.merge(cast[(cast.name=='Keanu Reeves') & (cast.n==1)], release_dates[release_dates.country=='USA'], how='inner').sort_values('date')
# Out:
#                                title  year          name   type  \
# 20                  The Night Before  1988  Keanu Reeves  actor
# 3   Bill & Ted's Excellent Adventure  1989  Keanu Reeves  actor
# 2         Bill & Ted's Bogus Journey  1991  Keanu Reeves  actor
# 12                     Little Buddha  1993  Keanu Reeves  actor
# 13                             Speed  1994  Keanu Reeves  actor
# 10                   Johnny Mnemonic  1995  Keanu Reeves  actor
# 1               A Walk in the Clouds  1995  Keanu Reeves  actor
# 4                     Chain Reaction  1996  Keanu Reeves  actor
# 6                  Feeling Minnesota  1996  Keanu Reeves  actor
# 17              The Devil's Advocate  1997  Keanu Reeves  actor
# 19                        The Matrix  1999  Keanu Reeves  actor
# 21                  The Replacements  2000  Keanu Reeves  actor
# 15                    Sweet November  2001  Keanu Reeves  actor
# 7                          Hard Ball  2001  Keanu Reeves  actor
# ...

# %% [markdown]
# ### Section III - Q4: Make a bar plot showing the months in which movies with Keanu Reeves tend to be released in the USA?

# %%
pd.merge(cast[(cast.name=='Keanu Reeves')], release_dates[release_dates.country=='USA'], how='inner').date.dt.month.value_counts().sort_index().plot(kind='bar')
plt.xlabel('month of release date')
plt.ylabel('# of movies')
plt.title('the months in which movies with Keanu Reeves tend to be released in the USA')
# Out:
# Text(0.5, 1.0, 'the months in which movies with Keanu Reeves tend to be released in the USA')

# %% [markdown]
# ### Section III - Q5: Make a bar plot showing the years in which movies with Ian McKellen tend to be released in the USA?

# %%
pd.merge(cast[(cast.name=='Ian McKellen')], release_dates[release_dates.country=='USA'], how='inner').date.dt.year.value_counts().sort_index().plot(kind='bar')
plt.xlabel('Year of release date')
plt.ylabel('# of movies')
plt.title('the years in which movies with Ian McKellen tend to be released in the USA')
# Out:
# Text(0.5, 1.0, 'the years in which movies with Ian McKellen tend to be released in the USA')
